# %%
import pandas as pd
import numpy as np
import os
import csv
pd.set_option('display.max_columns', 380)
pd.set_option('display.width', 140)
pd.set_option('display.max_rows', 380)
import seaborn as sns
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
# %matplotlib inline

# %%
os.getcwd()
os.chdir('downloads')

# %%
df=pd.read_excel("Absenteeism_at_work_Project.xls")

# %%
#df.head()
#df.shape
df.dtypes
# Out:
# ID                                   int64
# Reason for absence                 float64
# Month of absence                   float64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense             float64
# Distance from Residence to Work    float64
# Service time                       float64
# Age                                float64
# Work load Average/day              float64
# Hit target                         float64
# Disciplinary failure               float64
# Education                          float64
# Son                                float64
# Social drinker                     float64
# Social smoker                      float64
# Pet                                float64
# Weight                             float64
# Height                             float64
# Body mass index                    float64
# Absenteeism time in hours          float64
# dtype: object

# %%
#df['Month.of.absence']= df['Month.of.absence'].replace(0,np.nan)

ID = df.loc[df['Transportation expense'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Transportation expense'].isnull()) & (df['ID']==i)),'Transportation expense']= df['Transportation expense'][(df['ID']==i) & (df['Transportation expense'].notnull())].values[0]

# %%
ID = df.loc[df['Age'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Age'].isnull()) & (df['ID']==i)),'Age']= df['Age'][(df['ID']==i) & (df['Age'].notnull())].values[0]

# %%
ID = df.loc[df['Distance from Residence to Work'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Distance from Residence to Work'].isnull()) & (df['ID']==i)),'Distance from Residence to Work']= df['Distance from Residence to Work'][(df['ID']==i) & (df['Distance from Residence to Work'].notnull())].values[0]

# %%
ID = df.loc[df['Service time'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Service time'].isnull()) & (df['ID']==i)),'Service time']= df['Service time'][(df['ID']==i) & (df['Service time'].notnull())].values[0]

# %%
ID = df.loc[df['Education'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Education'].isnull()) & (df['ID']==i)),'Education']= df['Education'][(df['ID']==i) & (df['Education'].notnull())].values[0]

# %%
ID = df.loc[df['Son'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Son'].isnull()) & (df['ID']==i)),'Son']= df['Son'][(df['ID']==i) & (df['Son'].notnull())].values[0]

# %%
ID = df.loc[df['Social drinker'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Social drinker'].isnull()) & (df['ID']==i)),'Social drinker']= df['Social drinker'][(df['ID']==i) & (df['Social drinker'].notnull())].values[0]

# %%
ID = df.loc[df['Social smoker'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Social smoker'].isnull()) & (df['ID']==i)),'Social smoker']= df['Social smoker'][(df['ID']==i) & (df['Social smoker'].notnull())].values[0]

# %%
ID = df.loc[df['Pet'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Pet'].isnull()) & (df['ID']==i)),'Pet']= df['Pet'][(df['ID']==i) & (df['Pet'].notnull())].values[0]

# %%
ID = df.loc[df['Weight'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Weight'].isnull()) & (df['ID']==i)),'Weight']= df['Weight'][(df['ID']==i) & (df['Weight'].notnull())].values[0]

# %%
ID = df.loc[df['Height'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Height'].isnull()) & (df['ID']==i)),'Height']= df['Height'][(df['ID']==i) & (df['Height'].notnull())].values[0]

# %%
ID = df.loc[df['Body mass index'].isnull(),'ID'].values
for i in ID:
    df.loc[((df['Body mass index'].isnull()) & (df['ID']==i)),'Body mass index']= df['Body mass index'][(df['ID']==i) & (df['Body mass index'].notnull())].values[0]

# %%
# Repeatedly execute until no errors as empty array breaks execution before complete imputatuion
ID = df.loc[df['Work load Average/day '].isnull(),'Hit target'].values
for i in ID:
    df.loc[((df['Work load Average/day '].isnull()) & (df['Hit target']==i) & (df['Month of absence']==df.loc[df['Work load Average/day '].isnull(),'Month of absence'].values[0])),'Work load Average/day '] = df.loc[((df['Work load Average/day '].notnull()) & (df['Hit target']==i) & (df['Month of absence']== df.loc[df['Work load Average/day '].isnull() ,'Month of absence'].values[0])),'Work load Average/day '].values[0]

# %%
# Repeatedly execute until no errors as empty array breaks execution before complete imputatuion
ID = df.loc[df['Hit target'].isnull(),'Work load Average/day '].values
for i in ID:
    df.loc[((df['Hit target'].isnull()) & (df['Work load Average/day ']==i) & (df['Month of absence']==df.loc[df['Hit target'].isnull(),'Month of absence'].values[0])),'Hit target'] = df.loc[((df['Hit target'].notnull()) & (df['Work load Average/day ']==i) & (df['Month of absence']== df.loc[df['Hit target'].isnull() ,'Month of absence'].values[0])),'Hit target'].values[0]

# %%
ID = df.loc[df['Month of absence'].isnull(),'Work load Average/day '].values
for i in ID:
    df.loc[((df['Month of absence'].isnull()) & (df['Work load Average/day ']==i)),'Month of absence']= df['Month of absence'][(df['Work load Average/day ']==i) & (df['Month of absence'].notnull())].values[0]

# %%
ID = df.loc[df['Absenteeism time in hours'].isnull(),'Reason for absence'].values
for i in ID:
    df.loc[(df['Absenteeism time in hours'].isnull()) & (df['Reason for absence']==i),'Absenteeism time in hours'] = df.loc[df['Reason for absence']==i,'Absenteeism time in hours'].median()

# %%
ID = df.loc[df['Reason for absence'].isnull(),'Absenteeism time in hours'].values
for i in ID:
    df.loc[(df['Reason for absence'].isnull()) & (df['Absenteeism time in hours']==i),'Reason for absence'] = df.loc[df['Absenteeism time in hours']==i,'Reason for absence'].median()

# %%
ID = df.loc[df['Disciplinary failure'].isnull(),'Reason for absence'].values
for i in ID:
    if(i==0):
        df.loc[((df['Disciplinary failure'].isnull()) & (df['Reason for absence']==i)) ,'Disciplinary failure'] = 1
    else:
        df.loc[((df['Disciplinary failure'].isnull()) & (df['Reason for absence']==i)),'Disciplinary failure'] = 0

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
#----------------------Outlier analysis ----------------
data= df.copy()

# %%
data.columns.values
# Out:
# array(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense',
#        'Distance from Residence to Work', 'Service time', 'Age',
#        'Work load Average/day ', 'Hit target', 'Disciplinary failure',
#        'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet',
#        'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours'],
#       dtype=object)

# %%
catnames = ['ID','Reason for absence','Month of absence','Day of the week','Seasons','Disciplinary failure','Education', 'Son', 'Social drinker', 'Social smoker', 'Pet']

# %%
contnames = ['Transportation expense','Distance from Residence to Work', 'Service time', 'Age','Work load Average/day ', 'Hit target','Weight', 'Height', 'Body mass index', 'Absenteeism time in hours']

# %%
contnames
# Out:
# ['Transportation expense',
#  'Distance from Residence to Work',
#  'Service time',
#  'Age',
#  'Work load Average/day ',
#  'Hit target',
#  'Weight',
#  'Height',
#  'Body mass index',
#  'Absenteeism time in hours']

# %%
for i in contnames:
    print(i)
    plt.boxplot(data[i])
    plt.xlabel(i)
    plt.ylabel('Values')
    plt.title("BoxPlot of "+i)
    plt.show()
# Out:
# Transportation expense
# Distance from Residence to Work
# Service time
# Age
# Work load Average/day
# Hit target
# Weight
# Height
# Body mass index
# Absenteeism time in hours

# %%
for i in contnames:
    print(i)
    q75,q25= np.percentile(data.loc[:,i],[75,25])
    iqr= q75-q25
    minimum= q25-(iqr*1.5)
    maximum= q75+(iqr*1.5)
    print(minimum)
    print(maximum)
    print(iqr)

#Capping outliers at max and min    
    data.loc[data[i]< minimum,i] = minimum
    data.loc[data[i]> maximum,i] = maximum
# Out:
# Transportation expense
# 57.5
# 381.5
# 81.0
# Distance from Residence to Work
# -35.0
# 101.0
# 34.0
# Service time
# -1.5
# 26.5
# 7.0
# Age
# 17.5
# 53.5
# 9.0
# Work load Average/day
# 169642.0
# 368962.0
# 49830.0
# Hit target
# 87.0
# 103.0
# 4.0
# Weight
# 39.0
# 119.0
# 20.0
# Height
# 164.5
# 176.5
# 3.0
# Body mass index
# 13.5
# 41.5
# 7.0
# Absenteeism time in hours
# -7.0
# 17.0
# 6.0

# %%
#Check NA in dataset-
data.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
data 
# 3 variables have negative minimum values but looking at the boxplot we can confirm that there 
#are no outliers falling below the lower fence
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  Transportation expense  Distance from Residence to Work  \
# 0    11                26.0               7.0                3        1                   289.0                             36.0
# 1    36                 0.0               7.0                3        1                   118.0                             13.0
# 2     3                23.0               7.0                4        1                   179.0                             51.0
# 3     7                 7.0               7.0                5        1                   279.0                              5.0
# 4    11                23.0               7.0                5        1                   289.0                             36.0
# 5     3                23.0               7.0                6        1                   179.0                             51.0
# ...

# %%
data.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
#---------------Feature selection-------------

df= data.copy()
data= df.copy()

# %%
#Correlation analysis for numeric variables-

#extract only numeric variables in dataframe for correlation-
df_corr = data.loc[:,contnames]

#Generate correlation matrix-
corr_matrix= df_corr.corr()

# %%
corr_matrix
# Out:
#                                  Transportation expense  Distance from Residence to Work  Service time       Age  Work load Average/day   \
# Transportation expense                         1.000000                         0.262825     -0.358638 -0.234663                0.003039
# Distance from Residence to Work                0.262825                         1.000000      0.128687 -0.141167               -0.070633
# Service time                                  -0.358638                         0.128687      1.000000  0.682016               -0.007310
# Age                                           -0.234663                        -0.141167      0.682016  1.000000               -0.038998
# Work load Average/day                          0.003039                        -0.070633     -0.007310 -0.038998                1.000000
# Hit target                                    -0.082951                         0.002353      0.015246 -0.025773               -0.071211
# ...

# %%
#Corrleation plot-

#Set height and width of page-
f,ax= plt.subplots(figsize=(10,8))

#Plot-
sns.heatmap(corr_matrix,mask=np.zeros_like(corr_matrix,dtype=np.bool),cmap=sns.diverging_palette(240,120,as_cmap=True),
           square=True,ax=ax,annot=True)
plt.title("Correlation Plot")
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %%
catnames
# Out:
# ['ID',
#  'Reason for absence',
#  'Month of absence',
#  'Day of the week',
#  'Seasons',
#  'Disciplinary failure',
#  'Education',
#  'Son',
#  'Social drinker',
#  'Social smoker',
#  'Pet']

# %%
#loop for chi square values
for i in catnames:
    print(i)
    chi2, p, dof, ex = chi2_contingency(pd.crosstab(data['Absenteeism time in hours'], data[i]))
    print(p)
# Out:
# ID
# 2.2365273988343456e-18
# Reason for absence
# 7.286648099847831e-164
# Month of absence
# 4.2684498955085155e-14
# Day of the week
# 0.022796924191761825
# Seasons
# 5.362095696190738e-10
# Disciplinary failure
# 3.9490277004803864e-134
# Education
# 0.31031968497259027
# Son
# 1.374139582757932e-10
# Social drinker
# 0.0002987130412010769
# Social smoker
# 0.19661000773680085
# Pet
# 1.2450025241126808e-05

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data = data.drop(["Weight","Social smoker","Education"],axis=1)

# %%
data.shape
# Out:
# (740, 18)

# %%
#---------------Feature scaling-------------
df= data.copy()
data= df.copy()

# %%
data.columns
contnames = ['Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age','Work load Average/day ', 'Hit target','Height', 'Body mass index','Absenteeism time in hours']
catnames = ['ID', 'Reason for absence','Month of absence', 'Day of the week','Seasons','Disciplinary failure', 'Son', 'Social drinker','Pet',]

# %%
for i in contnames:
    print(i)
    # %matplotlib inline  
    plt.hist(data[i], bins='auto',color='green')
    plt.ylabel("Density")
    plt.show()    #From below lot its showing data is not uniformaly distributed, so we will do normalization for dataset.
# Out:
# Transportation expense
# Distance from Residence to Work
# Service time
# Age
# Work load Average/day
# Hit target
# Height
# Body mass index
# Absenteeism time in hours

# %%
#Normalization
for i in contnames:
    print(i)
    data[i] = (data[i] - min(data[i]))/(max(data[i]) - min(data[i]))
# Out:
# Transportation expense
# Distance from Residence to Work
# Service time
# Age
# Work load Average/day
# Hit target
# Height
# Body mass index
# Absenteeism time in hours

# %%
data
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  Transportation expense  Distance from Residence to Work  \
# 0    11                26.0               7.0                3        1                0.648956                         0.659574
# 1    36                 0.0               7.0                3        1                0.000000                         0.170213
# 2     3                23.0               7.0                4        1                0.231499                         0.978723
# 3     7                 7.0               7.0                5        1                0.611006                         0.000000
# 4    11                23.0               7.0                5        1                0.648956                         0.659574
# 5     3                23.0               7.0                6        1                0.231499                         0.978723
# ...

# %% [markdown]
# ### Model Development

# %%
#Import libraries-
from sklearn.metrics import accuracy_score
#from sklearn.cross_validation import train_test_split 
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split

# %%
data = pd.get_dummies(data,columns=catnames)

# %%
#split data for predictor and target seperatly-
X= data.drop(['Absenteeism time in hours'],axis=1)
y= data['Absenteeism time in hours']

#Divide data into train and test-
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=.20,random_state=220192)

# %%
y_train
# Out:
# 595    0.117647
# 40     0.117647
# 497    0.176471
# 738    0.000000
# 666    0.117647
# 164    1.000000
# 240    0.470588
# 136    0.176471
# 337    1.000000
# 424    0.117647
# 499    0.117647
# 576    0.470588
# 209    0.235294
# 485    0.470588
# 87     1.000000
# 481    0.058824
# 646    0.176471
# 24     0.470588
# 353    0.235294
# 598    0.176471
# 395    0.470588
# 522    0.058824
# 72     0.470588
# 3      0.235294
# 433    0.176471
# 99     1.000000
# 71     0.294118
# 156    0.470588
# 712    0.470588
# 459    0.470588
# 718    0.117647
# 397    0.470588
# 107    0.176471
# 222    1.000000
# 416    0.235294
# 378    0.470588
# 75     0.470588
# 115    0.058824
# 237    0.470588
# 210    0.117647
# 244    0.470588
# 375    0.117647
# 369    0.117647
# 721    0.470588
# 92     0.176471
# 181    0.117647
# 315    0.294118
# 489    0.941176
# 178    0.941176
# 578    0.117647
# 453    0.117647
# 39     0.235294
# 330    0.470588
# 84     0.294118
# 498    0.117647
# ...

# %% [markdown]
# # Decision Tree

# %%
from sklearn.metrics import r2_score
from scipy import stats
from sklearn.tree import DecisionTreeRegressor

#Decision tree for regression-
DT_model= DecisionTreeRegressor().fit(X_train,y_train)

#model prediction on train data-
DT_train= DT_model.predict(X_train)

#model prediction on test data-
DT_test= DT_model.predict(X_test)

#RMSE for train data-
RMSE_train=np.sqrt(mean_squared_error(y_train,DT_train))

#RMSE for test data-
RMSE_test=np.sqrt(mean_squared_error(y_test, DT_test))

#r2 value for train data-
r2_train= r2_score(y_train,DT_train)

#r2 value for test data-
r2_test=r2_score(y_test,DT_test)

print("Root Mean Square Rate for train data="+str(RMSE_train))
print("Root Mean Square Rate for test data="+str(RMSE_test))
print("R^2_score for train data="+str(r2_train))
print("R^2_score for test data="+str(r2_test))

#Root Mean Square Rate for train data=0.052468745289057435
#Root Mean Square Rate for test data=0.25044771158101437
#R^2_score for train data=0.9613409383673635
#R^2_score for test data=-0.05693086877204934
# Out:
# Root Mean Square Rate for train data=0.052468745289057435
# Root Mean Square Rate for test data=0.25044771158101437
# R^2_score for train data=0.9613409383673635
# R^2_score for test data=-0.05693086877204934

# %% [markdown]
# # Random Forest

# %%
# from sklearn.ensemble import RandomForestRegressor

#Random Forest for regression-
RF_model= RandomForestRegressor(n_estimators=300).fit(X_train,y_train)

#model prediction on train data-
RF_train= RF_model.predict(X_train)

#model prediction on test data-
RF_test= RF_model.predict(X_test)

#RMSE for train data-
RMSE_train=np.sqrt(mean_squared_error(y_train, RF_train))

#RMSE for test data-
RMSE_test=np.sqrt(mean_squared_error(y_test, RF_test))

#r2 value for train data-
r2_train= r2_score(y_train,RF_train)

#r2 value for test data-
r2_test=r2_score(y_test,RF_test)

print("Root Mean Square Rate for train data="+str(RMSE_train))
print("Root Mean Square Rate for test data="+str(RMSE_test))
print("R^2_score for train data="+str(r2_train))
print("R^2_score for test data="+str(r2_test))

#Root Mean Square Rate for train data=0.08854115298612367
#Root Mean Square Rate for test data=0.19618131056101704
#R^2_score for train data=0.8899119201770845
#R^2_score for test data=0.35147352594189385
# Out:
# Root Mean Square Rate for train data=0.08854115298612367
# Root Mean Square Rate for test data=0.19618131056101704
# R^2_score for train data=0.8899119201770845
# R^2_score for test data=0.35147352594189385

# %% [markdown]
# # Linear regression

# %%
#import libraries-
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

#Linear Regression model for regression-
LR_model= sm.OLS(y_train,X_train).fit()

#model prediction on train data-
LR_train= LR_model.predict(X_train)

#model prediction on test data-
LR_test= LR_model.predict(X_test)

#RMSE for train data-
RMSE_train=np.sqrt(mean_squared_error(y_train,LR_train))

#RMSE for test data-
RMSE_test=np.sqrt(mean_squared_error(y_test,LR_test))

#r2 for train data-
r2_train=r2_score(y_train,LR_train)

#r2 for test data-
r2_test=r2_score(y_test,LR_test)

print("Root Mean Square Rate for train data="+str(RMSE_train))
print("Root Mean Square Rate for test data="+str(RMSE_test))
print("R^2_score for train data="+str(r2_train))
print("R^2_score for test data="+str(r2_test))

#Root Mean Square Rate for train data=0.18189582692116452
#Root Mean Square Rate for test data=0.2025154298013779
#R^2_score for train data=0.5353826519020205
#R^2_score for test data=0.30891943020197454
# Out:
# Root Mean Square Rate for train data=0.18189582692116452
# Root Mean Square Rate for test data=0.2025154298013779
# R^2_score for train data=0.5353826519020205
# R^2_score for test data=0.30891943020197454
